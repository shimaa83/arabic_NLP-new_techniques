# %%
import splitfolders

# %%
input_folder='D:/NLP/arabic data set/Arabiya/'

# %%
input_folder='D:/NLP/arabic data set/testme/'

# %%
# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
splitfolders.ratio("D:/NLP/arabic data set/Arabiya/", output="D:/NLP/arabic data set/testme/",
    seed=1337, ratio=(.8, .1, .1), group_prefix=None, move=False) # default values
# Out:
# Copying files: 0 files [00:00, ? files/s]
# Copying files: 1 files [00:00,  3.09 files/s]
# Copying files: 106 files [00:00, 323.57 files/s]
# Copying files: 229 files [00:00, 598.67 files/s]
# Copying files: 347 files [00:00, 773.89 files/s]
# Copying files: 460 files [00:00, 880.96 files/s]
# Copying files: 580 files [00:00, 976.90 files/s]
# Copying files: 703 files [00:00, 1050.52 files/s]
# Copying files: 817 files [00:01, 1061.67 files/s]
# Copying files: 930 files [00:01, 1046.69 files/s]
# Copying files: 1039 files [00:01, 1049.49 files/s]
# Copying files: 1153 files [00:01, 1073.60 files/s]
# Copying files: 1268 files [00:01, 1094.04 files/s]
# Copying files: 1398 files [00:01, 1152.30 files/s]
# Copying files: 1520 files [00:01, 1169.80 files/s]
# Copying files: 1638 files [00:01, 1152.61 files/s]
# Copying files: 1754 files [00:01, 1132.43 files/s]
# Copying files: 1868 files [00:01, 1084.95 files/s]
# Copying files: 1978 files [00:02, 1056.96 files/s]
# ...
